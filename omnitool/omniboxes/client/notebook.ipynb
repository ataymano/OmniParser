# %% [markdown]
# # Test instance

# %%
import client
client.InstanceClient(port = 5000).ui()

# %% [markdown]
# # Test node

# %%
import client
c = client.NodeClient(port = 8000)
c.ui()

# %% [markdown]
# # Test master node

# %%
import client
c = client.MasterClient(port = 7000)

# %%
instance = c.get_instance()
print(instance)

# %%
c.screenshot(instance)

# %%
import actions
c.execute(instance, actions.click())

# %%
c.screenshot(instance)

# %%
c.ui()
